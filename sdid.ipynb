# %%
from synthdid.synthdid import Synthdid as sdid
from synthdid.get_data import quota, california_prop99

# %%
a = sdid(quota(), "country", "year", "quota", "womparl")

# %%
a.fit()

# %%
a.vcov()

# %%
cal = sdid(california_prop99(), "State", "Year", "treated", "PacksPerCapita").fit()

# %%
cal.vcov(method="placebo")

# %%
cal.att
# Out:
# -15.60383

# %%
quota_1 = quota().dropna(subset="lngdp")

# %%
from synthdid.utils import panel_matrices
from synthdid.get_data import quota
from synthdid.synthdid import Synthdid as sdid
quota_1 = quota().dropna(subset="lngdp")

# %%
b = sdid(quota_1, "country", 'year', 'quota', 'womparl', covariates=['lngdp'])

# %%
b.fit(cov_method='projected')

# %%
b.att
# Out:
# 8.05903

# %%
b.fit()
b.att
# Out:
# 8.04901

# %%
b.plot_outcomes()
